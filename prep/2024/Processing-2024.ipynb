# %%
class Document:
    def __init__(self, content, metadata=None, doc_id=None, num_chunks=None):
        self.content = content
        self.metadata = metadata if metadata is not None else {}
        self.id = doc_id if doc_id is not None else str(uuid.uuid4())
        self.num_chunks = num_chunks

    def add_metadata(self, key, value):
        """
        Adds a key-value pair to the document's metadata.

        :param key: The key for the metadata item.
        :param value: The value for the metadata item.
        """
        self.metadata[key] = value

    def __str__(self):
        """
        Returns a string representation of the document.

        :return: A string containing the content and metadata of the document.
        """
        return f"Content: {self.content}\nMetadata: {self.metadata}"


    def to_json(self):
        """ Convert the Document object to a JSON string """
        # Use a dictionary comprehension to handle the renaming of 'id' to 'doc_id'
        data = {k if k != 'id' else 'doc_id': v for k, v in self.__dict__.items()}
        return json.dumps(data)

    @classmethod
    def from_json(cls, json_str):
        """ Create a Document object from a JSON string """
        data = json.loads(json_str)
        return cls(**data)

# %%
import json
with open('../../data/2024/json/event_1dM9M_fuhrungsmodelle-der-zukunft.json', 'r') as file:
    data = json.load(file)

# %%
excluded_keys = ['Title', 'Description', 'Date', 'Location', 'Type']
difference = [key for key in data.keys() if key not in excluded_keys]

# %%
difference
# Out:
# ['Speakers']

# %%
content = f"""Title: {data['Title']}\nDescription: {data['Description']}\nDate: {data['Date']}\nLocation: {data['Location']}\nType: {data['Type']}"""

# %%
metadata = dict()
for key in difference:
    metadata[key]= data[key]

# %%
metadata
# Out:
# {'Speakers': ['Marit Heidrich',
#   'Mia Konew',
#   'Robert Kaletsch',
#   'Julia Seeliger']}

# %%
print(content)
# Out:
# Title: Führungsmodelle der Zukunft
# Description: No description found
# Date: Friday June 14, 2024 12:00 - 12:45 CEST
# Location: Innovation Stage
# Type: Zukunft der Arbeit, panel

# %%
import os
import json
import uuid

documents = []

def process_json_data(data, excluded_keys):
    # Process your JSON data here
    content = f"""Title: {data['Title']}\nDescription: {data['Description']}\nDate: {data['Date']}\nLocation: {data['Location']}\nType: {data['Type']}"""
    difference = [key for key in data.keys() if key not in excluded_keys]
    metadata = dict()
    for key in difference:
        metadata[key]= data[key]
    return Document(content, metadata=metadata)
    

# Path to the directory containing JSON files
folder_path = '../../data/2024/json'

# Loop through each file in the specified directory
for filename in os.listdir(folder_path):
    if filename.endswith('.json'):  # Check if the file is a JSON file
        file_path = os.path.join(folder_path, filename)  # Get the full path of the file
        with open(file_path, 'r') as file:
            try:
                data = json.load(file)  # Load the JSON data from the file
                documents.append(process_json_data(data, excluded_keys))
            except json.JSONDecodeError:
                print(f"Error decoding JSON from the file {filename}")

# %%
len(documents)
# Out:
# 106

# %%
def parse_event_details(event_string):
    # Split the input string into lines for easier parsing
    lines = event_string.split('\n')
    
    # Initialize dictionary to hold parsed data
    event_details = {}
    
    for line in lines:
        # Check if the line contains date and time information
        if 'Date:' in line:
            # Remove the label 'Datum:' and extra spaces
            date_time_info = line.replace('Date:', '').strip()
            
            # Find the index where the time starts (immediately after the year), if present
            time_start_index = date_time_info.find(':') - 2 if ':' in date_time_info else -1
            
            # Separate the day of the week
            day = date_time_info.split(' ')[0]
            
            if time_start_index != -1:
                # Extract the time information
                times = date_time_info[time_start_index:].split('-')
                start_time = times[0].strip()
                end_time = times[1].strip().split(' ')[0]  # Remove the timezone if present
            else:
                # No time given, set to a placeholder
                start_time = "None"
                end_time = "None"
            
            # Populate the event details dictionary
            event_details['day'] = day
            event_details['start_time'] = start_time
            event_details['end_time'] = end_time

    return event_details

# Example usage with a string that includes only the day
event_string_only_day = 'Titel: Breakfast for Camp Sleepers\nBeschreibung: No description found\nDate: Friday June 16, 2023\nOrt: Courtyard'

parsed_event_only_day = parse_event_details(event_string_only_day)
print(parsed_event_only_day)
# Out:
# {'day': 'Friday', 'start_time': 'None', 'end_time': 'None'}

# %%
for doc in documents:
    doc.add_metadata("date", parse_event_details(doc.content))

# %%
print(documents[0])
# Out:
# Content: Title: How to Businessplan
# Description: No description found
# Date: Friday June 14, 2024 10:00 - 10:45 CEST
# Location: Beachfront Tent
# Type:
# Metadata: {'Speakers': ['Mandy Semkow', 'Fabian Haushahn'], 'date': {'day': 'Friday', 'start_time': '10:00', 'end_time': '10:45'}}

# %%
for doc in documents:
    print(doc)
    print("###########")
# Out:
# Content: Title: How to Businessplan
# Description: No description found
# Date: Friday June 14, 2024 10:00 - 10:45 CEST
# Location: Beachfront Tent
# Type:
# Metadata: {'Speakers': ['Mandy Semkow', 'Fabian Haushahn'], 'date': {'day': 'Friday', 'start_time': '10:00', 'end_time': '10:45'}}
# ###########
# Content: Title: Neue Herausforderungen im Bereich von Open Source AI & LLM Security
# Description: No description found
# Date: Friday June 14, 2024 17:00 - 17:45 CEST
# Location: Garden Tent
# Type:
# Metadata: {'Speakers': ['Jake Petersen', 'Jan Monica'], 'date': {'day': 'Friday', 'start_time': '17:00', 'end_time': '17:45'}}
# ###########
# Content: Title: Verwaltung der Zukunft
# Description: No description found
# Date: Friday June 14, 2024 14:00 - 14:45 CEST
# Location: Tiny Rathaus
# Type: Zukunft der Verwaltung, talk
# Metadata: {'Speakers': ['Thilak Mahendran'], 'date': {'day': 'Friday', 'start_time': '14:00', 'end_time': '14:45'}}
# ###########
# Content: Title: Start A Startup Pitch Sessions
# Description: No description found
# Date: Friday June 14, 2024 17:00 - 17:45 CEST
# Location: Robotstage
# Type:
# Metadata: {'Speakers': ['Cynthia David', 'Mareike Springer'], 'date': {'day': 'Friday', 'start_time': '17:00', 'end_time': '17:45'}}
# ###########
# Content: Title: Get to know Artificial Intelligence Center Hamburg
# Description: No description found
# Date: Thursday June 13, 2024 18:00 - 18:45 CEST
# Location: Dock 1
# Type:
# Metadata: {'Speakers': [], 'date': {'day': 'Thursday', 'start_time': '18:00', 'end_time': '18:45'}}
# ###########
# Content: Title: Innovationsraum Hamburg-Schleswig-Holstein
# Description: No description found
# Date: Friday June 14, 2024 13:00 - 13:45 CEST
# Location: Transformation Stage
# Type:
# Metadata: {'Speakers': ['Steffen Brandt'], 'date': {'day': 'Friday', 'start_time': '13:00', 'end_time': '13:45'}}
# ###########
# Content: Title: Dritte Orte: Die Bibliothek der Zukunft
# Description: No description found
# Date: Friday June 14, 2024 14:00 - 14:45 CEST
# Location: Beachfront Tent
# Type:
# Metadata: {'Speakers': ['Martin Lätzel', 'Friederike Sablowski'], 'date': {'day': 'Friday', 'start_time': '14:00', 'end_time': '14:45'}}
# ###########
# Content: Title: Erfolg mit TikTok im Mittelstand
# Description: No description found
# Date: Friday June 14, 2024 12:00 - 12:45 CEST
# Location: Garden Tent
# Type: Future Skills
# Metadata: {'Speakers': ['Janine Kordes'], 'date': {'day': 'Friday', 'start_time': '12:00', 'end_time': '12:45'}}
# ###########
# Content: Title: Co2 Neutrales Bauen? Wunsch und Wirklichkeit
# Description: No description found
# Date: Friday June 14, 2024 13:00 - 13:45 CEST
# Location: Ocean
# Type:
# Metadata: {'Speakers': ['Till Peter Siemsen', 'Annika Mathe', 'Hoang Anh Nguyen'], 'date': {'day': 'Friday', 'start_time': '13:00', 'end_time': '13:45'}}
# ###########
# Content: Title: KI Meetup: Aric // Kiel.Ai = Coding.Waterkant
# Description: No description found
# Date: Friday June 14, 2024 12:00 - 12:45 CEST
# Location: Dock 1
# Type:
# Metadata: {'Speakers': ['Steffen Brandt'], 'date': {'day': 'Friday', 'start_time': '12:00', 'end_time': '12:45'}}
# ###########
# Content: Title: Wann wird AI endlich langweilig? Ein optmistischer Blick auf die Zukunft
# Description: No description found
# Date: Friday June 14, 2024 14:00 - 14:45 CEST
# Location: Rails
# Type:
# Metadata: {'Speakers': ['Gregor Schmalzried'], 'date': {'day': 'Friday', 'start_time': '14:00', 'end_time': '14:45'}}
# ###########
# Content: Title: Open Source Stammtisch
# Description: No description found
# Date: Friday June 14, 2024 15:00 - 15:45 CEST
# Location: Dock 1
# Type:
# Metadata: {'Speakers': ['Santosh Yadav', 'Julius Lipp', 'Gerardo Navarro Suarez', 'Stephan Raimer'], 'date': {'day': 'Friday', 'start_time': '15:00', 'end_time': '15:45'}}
# ###########
# Content: Title: Why Europe is leading the way in Open Source + AI
# Description: No description found
# Date: Friday June 14, 2024 14:00 - 14:45 CEST
# Location: Ocean
# Type:
# Metadata: {'Speakers': ['Steffen Brandt', 'Santosh Yadav', 'Julius Lipp', 'Jan Monica'], 'date': {'day': 'Friday', 'start_time': '14:00', 'end_time': '14:45'}}
# ###########
# Content: Title: eSport Job Session
# Description: No description found
# Date: Friday June 14, 2024 17:00 - 17:45 CEST
# Location: Beachfront Tent
# Type:
# Metadata: {'Speakers': ['Daniela Stahl'], 'date': {'day': 'Friday', 'start_time': '17:00', 'end_time': '17:45'}}
# ###########
# Content: Title: TinkerTank EKSH Abschlusspräsentation
# Description: No description found
# Date: Friday June 14, 2024 16:00 - 16:45 CEST
# Location: Garden Tent
# Type:
# Metadata: {'Speakers': ['Sandra Laffrenzen', 'Johannes May'], 'date': {'day': 'Friday', 'start_time': '16:00', 'end_time': '16:45'}}
# ###########
# Content: Title: Do’s und Don’ts beim Implementieren von KI im Mittelstand
# Description: No description found
# Date: Friday June 14, 2024 13:00 - 13:45 CEST
# Location: Garden Tent
# Type:
# Metadata: {'Speakers': ['Robert Kaletsch'], 'date': {'day': 'Friday', 'start_time': '13:00', 'end_time': '13:45'}}
# ###########
# Content: Title: Black Female Business
# Description: No description found
# Date: Friday June 14, 2024 14:00 - 14:45 CEST
# Location: Waterside Tent
# Type:
# Metadata: {'Speakers': ['Mariam Guédé'], 'date': {'day': 'Friday', 'start_time': '14:00', 'end_time': '14:45'}}
# ###########
# Content: Title: Cofounder Mix + Match
# Description: No description found
# Date: Friday June 14, 2024 15:00 - 15:45 CEST
# Location: Dock 2
# Type:
# Metadata: {'Speakers': ['Kathrin Knehans'], 'date': {'day': 'Friday', 'start_time': '15:00', 'end_time': '15:45'}}
# ###########
# Content: Title: No Code Innovation - dank Hi🧠 & Ki🤖
# Description: No description found
# Date: Friday June 14, 2024 10:00 - 10:45 CEST
# Location: Waterside Tent
# Type:
# Metadata: {'Speakers': ['Herwig (Hardy Sr.) Fölster'], 'date': {'day': 'Friday', 'start_time': '10:00', 'end_time': '10:45'}}
# ###########
# Content: Title: 12min.me HH meets Kiel better together
# Description: No description found
# Date: Friday June 14, 2024 17:00 - 17:45 CEST
# Location: Waterside Tent
# Type:
# Metadata: {'Speakers': ['Nina Bergner'], 'date': {'day': 'Friday', 'start_time': '17:00', 'end_time': '17:45'}}
# ###########
# Content: Title: How to become a Business Angel
# Description: No description found
# Date: Friday June 14, 2024 17:00 - 17:45 CEST
# Location: Ocean
# Type:
# Metadata: {'Speakers': ['Julian von Hassell'], 'date': {'day': 'Friday', 'start_time': '17:00', 'end_time': '17:45'}}
# ###########
# Content: Title: P & P Meeting
# Description: No description found
# Date: Friday June 14, 2024 16:00 - 16:45 CEST
# Location: Dock 2
# Type:
# Metadata: {'Speakers': ['Sylvie Rham'], 'date': {'day': 'Friday', 'start_time': '16:00', 'end_time': '16:45'}}
# ###########
# Content: Title: Startup Sessions mit Vision Period
# Description: No description found
# Date: Friday June 14, 2024 16:00 - 16:45 CEST
# Location: Waterside Tent
# Type: How to Startup, talk
# Metadata: {'Speakers': ['Fee Reinoso'], 'date': {'day': 'Friday', 'start_time': '16:00', 'end_time': '16:45'}}
# ###########
# Content: Title: Generative KI als Copilot in der Gründung
# Description: No description found
# Date: Friday June 14, 2024 16:00 - 16:45 CEST
# Location: Rails
# Type:
# Metadata: {'Speakers': ['Benjamin Peters', 'Roman Spendler'], 'date': {'day': 'Friday', 'start_time': '16:00', 'end_time': '16:45'}}
# ###########
# Content: Title: Masterclass // Futures Snack: Praktische Einführung in Futures Thinking
# Description:
#   Get your masterclass ticket here: https://waterkant24.eventbrite.deHole Dir hier Dein Masterclassticket: https://waterkant24.eventbrite.de
#
# Date: Thursday June 13, 2024 15:00 - 16:30 CEST
# Location: Dock 2
# Type:
# Metadata: {'Speakers': ['Elena Artiles Leyes', 'Katrina Günther', 'Gina Strecker'], 'date': {'day': 'Thursday', 'start_time': '15:00', 'end_time': '16:30'}}
# ###########
# Content: Title: Masterclass // Verhandlungsführung für Führungskräfte von Unternehmen und Startups
# Description:
#   Get your masterclass ticket here: https://waterkant24.eventbrite.deHole Dir hier Dein Masterclassticket: https://waterkant24.eventbrite.de
#
# Date: Thursday June 13, 2024 15:00 - 16:30 CEST
# Location: Dock 1
# Type:
# Metadata: {'Speakers': ['Dr. Martina Pesic'], 'date': {'day': 'Thursday', 'start_time': '15:00', 'end_time': '16:30'}}
# ###########
# Content: Title: Lean Startup für Impact Gründer:innen
# Description: No description found
# Date: Friday June 14, 2024 11:00 - 11:45 CEST
# Location: Waterside Tent
# Type: PHD
# Metadata: {'Speakers': ['Jonas Mielck'], 'date': {'day': 'Friday', 'start_time': '11:00', 'end_time': '11:45'}}
# ###########
# Content: Title: Masterclass // How to build a brand with purpose in the age of AI
# Description:
#   Get your masterclass ticket here: https://waterkant24.eventbrite.deHole Dir hier Dein Masterclassticket: https://waterkant24.eventbrite.de
#
# Date: Thursday June 13, 2024 15:00 - 16:30 CEST
# Location: Garden Tent
# Type:
# Metadata: {'Speakers': ['Pauls Spiers'], 'date': {'day': 'Thursday', 'start_time': '15:00', 'end_time': '16:30'}}
# ###########
# Content: Title: Masterclass // Engagement Marketing: Wie Unternehmen die nächste Generation Käufer:innen gezielt ansprechen
# Description:
#   Get your masterclass ticket here: https://waterkant24.eventbrite.deHole Dir hier Dein Masterclassticket: https://waterkant24.eventbrite.de
#
# Date: Thursday June 13, 2024 15:00 - 16:30 CEST
# Location: Beachfront Tent
# Type:
# Metadata: {'Speakers': ['Rasmus Hildebrand'], 'date': {'day': 'Thursday', 'start_time': '15:00', 'end_time': '16:30'}}
# ###########
# Content: Title: How to Chatbot - KI nutzbar machen
# Description: No description found
# Date: Friday June 14, 2024 15:00 - 15:45 CEST
# Location: Rails
# Type: Future Skills, talk
# Metadata: {'Speakers': ['Henrik Horst'], 'date': {'day': 'Friday', 'start_time': '15:00', 'end_time': '15:45'}}
# ###########
# Content: Title: Masterclass // Souveränität: Bedeutung & Tipps für Frauen
# Description:
#   Get your masterclass ticket here: https://waterkant24.eventbrite.deHole Dir hier Dein Masterclassticket: https://waterkant24.eventbrite.de
#
# Date: Thursday June 13, 2024 15:00 - 16:00 CEST
# Location: Waterside Tent
# Type:
# Metadata: {'Speakers': ['Norma Jensen'], 'date': {'day': 'Thursday', 'start_time': '15:00', 'end_time': '16:00'}}
# ###########
# Content: Title: Where is the money? Fördermöglichkeit für Gründer:innen
# Description: No description found
# Date: Friday June 14, 2024 11:00 - 11:45 CEST
# Location: Robotstage
# Type: How to Startup   PHD
# Metadata: {'Speakers': ['Mandy Semkow'], 'date': {'day': 'Friday', 'start_time': '11:00', 'end_time': '11:45'}}
# ###########
# Content: Title: Past & Future of AI content creation by an OpenAI ambassador
# Description: No description found
# Date: Friday June 14, 2024 12:00 - 12:45 CEST
# Location: Rails
# Type:
# Metadata: {'Speakers': ['Vladimir Alexeev (Merzmensch)'], 'date': {'day': 'Friday', 'start_time': '12:00', 'end_time': '12:45'}}
# ###########
# Content: Title: Future of Education
# Description: No description found
# Date: Friday June 14, 2024 10:00 - 10:45 CEST
# Location: Garden Tent
# Type:
# Metadata: {'Speakers': ['Hannah Bauhoff', 'Johannes May'], 'date': {'day': 'Friday', 'start_time': '10:00', 'end_time': '10:45'}}
# ###########
# Content: Title: Verkündung Sieger Plug & Play Pitch Competition
# Description: No description found
# Date: Thursday June 13, 2024 21:00 - 21:15 CEST
# Location: Innovation Stage
# Type:
# Metadata: {'Speakers': ['Hannah Pregla', 'Maya Wagner'], 'date': {'day': 'Thursday', 'start_time': '21:00', 'end_time': '21:15'}}
# ###########
# Content: Title: Social Entrepreneurship Pitch Session
# Description: No description found
# Date: Friday June 14, 2024 17:00 - 17:45 CEST
# Location: Ocean
# Type:
# Metadata: {'Speakers': ['Mustafa Eren'], 'date': {'day': 'Friday', 'start_time': '17:00', 'end_time': '17:45'}}
# ###########
# Content: Title: Creating Circular Cities
# Description: No description found
# Date: Friday June 14, 2024 11:00 - 11:45 CEST
# Location: Beachfront Tent
# Type: Future of the Planet
# Metadata: {'Speakers': ['Fridtjof Stechmann', 'Kirsten Müller'], 'date': {'day': 'Friday', 'start_time': '11:00', 'end_time': '11:45'}}
# ###########
# Content: Title: Ethische KI
# Description: No description found
# Date: Friday June 14, 2024 11:00 - 11:45 CEST
# Location: Dock 2
# Type:
# Metadata: {'Speakers': ['Ilay Mahbub'], 'date': {'day': 'Friday', 'start_time': '11:00', 'end_time': '11:45'}}
# ###########
# Content: Title: Wie blicken VCs auf Early Stage Startups
# Description: No description found
# Date: Friday June 14, 2024 15:00 - 15:45 CEST
# Location: Robotstage
# Type: How to Startup, talk
# Metadata: {'Speakers': ['Levke Salander'], 'date': {'day': 'Friday', 'start_time': '15:00', 'end_time': '15:45'}}
# ###########
# Content: Title: Mobilität der Zukunft
# Description: No description found
# Date: Friday June 14, 2024 12:00 - 12:45 CEST
# Location: Tiny Rathaus
# Type: Future of the Planet, talk
# Metadata: {'Speakers': ['Sven Ratjens'], 'date': {'day': 'Friday', 'start_time': '12:00', 'end_time': '12:45'}}
# ###########
# Content: Title: Making Social Work Future-Proof
# Description: No description found
# Date: Friday June 14, 2024 11:00 - 11:45 CEST
# Location: Tiny Rathaus
# Type:
# Metadata: {'Speakers': ['Dominik Haubrich'], 'date': {'day': 'Friday', 'start_time': '11:00', 'end_time': '11:45'}}
# ###########
# Content: Title: How to Zero Waste
# Description: No description found
# Date: Friday June 14, 2024 12:00 - 12:45 CEST
# Location: Forest
# Type: Future of the Planet, talk
# Metadata: {'Speakers': ['Marc Delaperrière', 'Marie Delaperrière'], 'date': {'day': 'Friday', 'start_time': '12:00', 'end_time': '12:45'}}
# ###########
# Content: Title: PHD Match Making
# Description: No description found
# Date: Friday June 14, 2024 11:00 - 11:45 CEST
# Location: Dock 1
# Type: PHD
# Metadata: {'Speakers': ['Jonas Mielck'], 'date': {'day': 'Friday', 'start_time': '11:00', 'end_time': '11:45'}}
# ###########
# Content: Title: Brand Design for impact founders
# Description: No description found
# Date: Friday June 14, 2024 10:00 - 10:45 CEST
# Location: Rails
# Type: PHD
# Metadata: {'Speakers': ['Rasmus Hildebrand'], 'date': {'day': 'Friday', 'start_time': '10:00', 'end_time': '10:45'}}
# ###########
# Content: Title: Bots & Company
# Description: No description found
# Date: Friday June 14, 2024 16:00 - 16:45 CEST
# Location: Waterside Tent
# Type:
# Metadata: {'Speakers': ['Doris Weßels'], 'date': {'day': 'Friday', 'start_time': '16:00', 'end_time': '16:45'}}
# ###########
# Content: Title: Die Zukünfte von Social Media
# Description: No description found
# Date: Friday June 14, 2024 16:00 - 16:45 CEST
# Location: Forest
# Type:
# Metadata: {'Speakers': ['Rasmus Hildebrand'], 'date': {'day': 'Friday', 'start_time': '16:00', 'end_time': '16:45'}}
# ###########
# Content: Title: Funding for Impact / Opening Workshop for PHDs
# Description: No description found
# Date: Thursday June 13, 2024 15:00 - 15:45 CEST
# Location: Robotstage
# Type: PHD
# Metadata: {'Speakers': ['Stefanie Reichelt'], 'date': {'day': 'Thursday', 'start_time': '15:00', 'end_time': '15:45'}}
# ###########
# Content: Title: Follow Up Führungsmodelle der Zukunft
# Description: No description found
# Date: Friday June 14, 2024 13:00 - 13:45 CEST
# Location: Dock 1
# Type:
# Metadata: {'Speakers': ['Marit Heidrich'], 'date': {'day': 'Friday', 'start_time': '13:00', 'end_time': '13:45'}}
# ###########
# Content: Title: Pitch Competition Startup Camp Schleswig-Holstein by Plug + Play
# Description: No description found
# Date: Thursday June 13, 2024 18:00 - 19:00 CEST
# Location: Future Stage
# Type:
# Metadata: {'Speakers': ['Hannah Pregla', 'Maya Wagner'], 'date': {'day': 'Thursday', 'start_time': '18:00', 'end_time': '19:00'}}
# ###########
# Content: Title: Anfängermindset als Grundlage von Innovation
# Description: No description found
# Date: Friday June 14, 2024 14:00 - 14:45 CEST
# Location: Forest
# Type: Future Skills, talk
# Metadata: {'Speakers': ['Dirk Ploss'], 'date': {'day': 'Friday', 'start_time': '14:00', 'end_time': '14:45'}}
# ###########
# Content: Title: eGov Meetup
# Description: No description found
# Date: Friday June 14, 2024 16:00 - 16:45 CEST
# Location: Dock 1
# Type: Zukunft der Verwaltung, Meetup
# Metadata: {'Speakers': ['Gerardo Navarro Suarez', 'Stephan Raimer'], 'date': {'day': 'Friday', 'start_time': '16:00', 'end_time': '16:45'}}
# ###########
# Content: Title: Music by MARLOT & Karpov 🎶
# Description: No description found
# Date: Thursday June 13, 2024 21:00 - 22:00 CEST
# Location: Innovation Stage
# Type: Extending Arts & Reality
# Metadata: {'Speakers': [], 'date': {'day': 'Thursday', 'start_time': '21:00', 'end_time': '22:00'}}
# ###########
# Content: Title: Prompt Battle
# Description: No description found
# Date: Thursday June 13, 2024 20:00 - 20:45 CEST
# Location: Innovation Stage
# Type:
# Metadata: {'Speakers': [], 'date': {'day': 'Thursday', 'start_time': '20:00', 'end_time': '20:45'}}
# ###########
# Content: Title: Holy Moly - wie soziale Innovationen entstehen
# Description: No description found
# Date: Friday June 14, 2024 15:00 - 15:45 CEST
# Location: Garden Tent
# Type:
# Metadata: {'Speakers': ['Inken Reimer'], 'date': {'day': 'Friday', 'start_time': '15:00', 'end_time': '15:45'}}
# ###########
# Content: Title: Grand Opening
# Description: No description found
# Date: Thursday June 13, 2024 17:00 - 17:45 CEST
# Location: Future Stage
# Type:
# Metadata: {'Speakers': ['Julia Carstens', 'Anne Wichmann', 'Mandy Semkow', 'Jonas Witt'], 'date': {'day': 'Thursday', 'start_time': '17:00', 'end_time': '17:45'}}
# ###########
# Content: Title: Meditationsworkshop
# Description: No description found
# Date: Friday June 14, 2024 14:00 - 14:45 CEST
# Location: Dock 2
# Type:
# Metadata: {'Speakers': ['Levke Svea Spinger'], 'date': {'day': 'Friday', 'start_time': '14:00', 'end_time': '14:45'}}
# ###########
# Content: Title: Zukunft des Journalismus
# Description: No description found
# Date: Friday June 14, 2024 14:00 - 14:45 CEST
# Location: Innovation Stage
# Type: Zukunft der Verwaltung, panel
# Metadata: {'Speakers': [], 'date': {'day': 'Friday', 'start_time': '14:00', 'end_time': '14:45'}}
# ###########
# Content: Title: Mindful Startup Training
# Description: No description found
# Date: Friday June 14, 2024 13:00 - 13:45 CEST
# Location: Rails
# Type:
# Metadata: {'Speakers': ['Dr. Malte Krohn'], 'date': {'day': 'Friday', 'start_time': '13:00', 'end_time': '13:45'}}
# ###########
# Content: Title: Food, Match + Making - Mittelstand meets Startup
# Description: No description found
# Date: Friday June 14, 2024 12:00 - 12:45 CEST
# Location: Beachfront Tent
# Type:
# Metadata: {'Speakers': ['Henning Rabe | Felix Doobe'], 'date': {'day': 'Friday', 'start_time': '12:00', 'end_time': '12:45'}}
# ###########
# Content: Title: Behind the Scenes of Impact Investment
# Description: No description found
# Date: Friday June 14, 2024 14:00 - 14:45 CEST
# Location: Innovation Stage
# Type:
# Metadata: {'Speakers': ['Alina Klarner', 'Heidrun Twesten', 'Maike Haase'], 'date': {'day': 'Friday', 'start_time': '14:00', 'end_time': '14:45'}}
# ###########
# Content: Title: Zukunftsdenken für den Mittelstand trainieren
# Description: No description found
# Date: Friday June 14, 2024 11:00 - 11:45 CEST
# Location: Garden Tent
# Type: Future Skills   Zukunft der Arbeit
# Metadata: {'Speakers': ['Alice Rombach'], 'date': {'day': 'Friday', 'start_time': '11:00', 'end_time': '11:45'}}
# ###########
# Content: Title: Investment Vernissage // Invitation only
# Description: No description found
# Date: Thursday June 13, 2024 19:30 - 21:00 CEST
# Location: Waterside Tent
# Type:
# Metadata: {'Speakers': ['Jonas Mielck'], 'date': {'day': 'Thursday', 'start_time': '19:30', 'end_time': '21:00'}}
# ###########
# Content: Title: Livepodcast Equality 365 - Der erste inklusive Incubator
# Description: No description found
# Date: Friday June 14, 2024 15:00 - 15:45 CEST
# Location: Innovation Stage
# Type: How to Startup, Podcast
# Metadata: {'Speakers': ['Sophie Dienberg', 'Isabel Gebien'], 'date': {'day': 'Friday', 'start_time': '15:00', 'end_time': '15:45'}}
# ###########
# Content: Title: Adding Accessiblity made it worse but why?
# Description: No description found
# Date: Friday June 14, 2024 10:00 - 10:45 CEST
# Location: Ocean
# Type: Future Skills, talk
# Metadata: {'Speakers': ['Sabrina Jodexni'], 'date': {'day': 'Friday', 'start_time': '10:00', 'end_time': '10:45'}}
# ###########
# Content: Title: Content Creation mit KI
# Description: No description found
# Date: Friday June 14, 2024 13:00 - 13:45 CEST
# Location: Forest
# Type: Future Skills, talk
# Metadata: {'Speakers': ['Inken Paland'], 'date': {'day': 'Friday', 'start_time': '13:00', 'end_time': '13:45'}}
# ###########
# Content: Title: Early Stage Pitches - Demo Day Start A Startup
# Description: No description found
# Date: Friday June 14, 2024 17:00 - 17:45 CEST
# Location: Robotstage
# Type: How to Startup, Pitch
# Metadata: {'Speakers': ['Cynthia David', 'Mareike Springer'], 'date': {'day': 'Friday', 'start_time': '17:00', 'end_time': '17:45'}}
# ###########
# Content: Title: Die Zukünfte des Internets sind feministisch
# Description: No description found
# Date: Friday June 14, 2024 13:00 - 13:45 CEST
# Location: Waterside Tent
# Type:
# Metadata: {'Speakers': ['Katrina Günther', 'Quincey Stumptner'], 'date': {'day': 'Friday', 'start_time': '13:00', 'end_time': '13:45'}}
# ###########
# Content: Title: Early Stage Pitches
# Description: No description found
# Date: Friday June 14, 2024 10:00 - 10:45 CEST
# Location: Robotstage
# Type:
# Metadata: {'Speakers': ['Cynthia David', 'Mareike Springer'], 'date': {'day': 'Friday', 'start_time': '10:00', 'end_time': '10:45'}}
# ###########
# Content: Title: Führungsmodelle der Zukunft
# Description: No description found
# Date: Friday June 14, 2024 12:00 - 12:45 CEST
# Location: Innovation Stage
# Type: Zukunft der Arbeit, panel
# Metadata: {'Speakers': ['Marit Heidrich', 'Mia Konew', 'Robert Kaletsch', 'Julia Seeliger'], 'date': {'day': 'Friday', 'start_time': '12:00', 'end_time': '12:45'}}
# ###########
# Content: Title: Nachhaltigkeit als Unternehmenspraxis
# Description: No description found
# Date: Friday June 14, 2024 11:00 - 11:45 CEST
# Location: Forest
# Type: Zukunft der Arbeit
# Metadata: {'Speakers': ['Lisa Buddemeier', 'Christian Koch'], 'date': {'day': 'Friday', 'start_time': '11:00', 'end_time': '11:45'}}
# ###########
# Content: Title: Status Quo Energiewende 🔋
# Description: No description found
# Date: Friday June 14, 2024 15:00 - 15:45 CEST
# Location: Ocean
# Type:
# Metadata: {'Speakers': ['Sascha Pallenberg'], 'date': {'day': 'Friday', 'start_time': '15:00', 'end_time': '15:45'}}
# ###########
# Content: Title: Best practice: Mental Health im Unternehmen
# Description: No description found
# Date: Friday June 14, 2024 10:00 - 10:45 CEST
# Location: Transformation Stage
# Type: Zukunft der Arbeit
# Metadata: {'Speakers': ['Hilke Johanna Wilts', 'Britta Brechtel'], 'date': {'day': 'Friday', 'start_time': '10:00', 'end_time': '10:45'}}
# ###########
# Content: Title: Food, Match & Making - Innovationen im Foodbereich
# Description: No description found
# Date: Friday June 14, 2024 11:00 - 11:45 CEST
# Location: Transformation Stage
# Type:
# Metadata: {'Speakers': [], 'date': {'day': 'Friday', 'start_time': '11:00', 'end_time': '11:45'}}
# ###########
# Content: Title: Raus aus der großen Erschöpfung
# Description: No description found
# Date: Friday June 14, 2024 16:00 - 16:45 CEST
# Location: Innovation Stage
# Type: Zukunft der Arbeit, talk
# Metadata: {'Speakers': ['Hans Rusinek'], 'date': {'day': 'Friday', 'start_time': '16:00', 'end_time': '16:45'}}
# ###########
# Content: Title: Growth Stage Pitches powered by Kitz
# Description: No description found
# Date: Friday June 14, 2024 14:00 - 14:45 CEST
# Location: Robotstage
# Type: How to Startup, Pitch
# Metadata: {'Speakers': ['Andree Mehrens'], 'date': {'day': 'Friday', 'start_time': '14:00', 'end_time': '14:45'}}
# ###########
# Content: Title: Gemeinwohlökonomie als Recruitingsbooster
# Description: No description found
# Date: Friday June 14, 2024 16:00 - 16:45 CEST
# Location: Ocean
# Type: Future of the Planet   Zukunft der Arbeit
# Metadata: {'Speakers': ['Lisa Buddemeier', 'Christian Koch'], 'date': {'day': 'Friday', 'start_time': '16:00', 'end_time': '16:45'}}
# ###########
# Content: Title: Organisationsmodelle der Zukunft (Alles Holo oder was?)
# Description: No description found
# Date: Friday June 14, 2024 14:00 - 14:45 CEST
# Location: Beachfront Tent
# Type: Zukunft der Arbeit, talk
# Metadata: {'Speakers': ['Sonja Sinz'], 'date': {'day': 'Friday', 'start_time': '14:00', 'end_time': '14:45'}}
# ###########
# Content: Title: Tech for Good – Immersive Storytelling for Social & Environmental Impact
# Description: No description found
# Date: Friday June 14, 2024 10:00 - 10:45 CEST
# Location: Forest
# Type: Extending Arts & Reality
# Metadata: {'Speakers': ['Janieke Bekasinski', 'Kata Börönte'], 'date': {'day': 'Friday', 'start_time': '10:00', 'end_time': '10:45'}}
# ###########
# Content: Title: Reconceptualize Value: Unternehmerische Wertschöpfung für die sozial-ökologische Transformation
# Description: No description found
# Date: Friday June 14, 2024 15:00 - 15:45 CEST
# Location: Garden Tent
# Type: Zukunft der Arbeit, talk
# Metadata: {'Speakers': ['Hanna Rausch', 'Lara Schimpf'], 'date': {'day': 'Friday', 'start_time': '15:00', 'end_time': '15:45'}}
# ###########
# Content: Title: Extended Learning: Wissensvermittlung durch immersive Medien
# Description: No description found
# Date: Friday June 14, 2024 13:00 - 13:45 CEST
# Location: Robotstage
# Type: Extending Arts & Reality, panel
# Metadata: {'Speakers': ['Prof. Dr. Rupert-Kruse', 'Sandra Schramke', 'Stefan Johnigk'], 'date': {'day': 'Friday', 'start_time': '13:00', 'end_time': '13:45'}}
# ###########
# Content: Title: Deep Sea AR Experience
# Description: No description found
# Date: Thursday June 13, 2024 18:00 - 18:45 CEST
# Location: Ocean
# Type:
# Metadata: {'Speakers': ['Anne Wichmann'], 'date': {'day': 'Thursday', 'start_time': '18:00', 'end_time': '18:45'}}
# ###########
# Content: Title: Launch of Startup Guide Kielregion
# Description: No description found
# Date: Friday June 14, 2024 18:15 - 18:30 CEST
# Location: Innovation Stage
# Type:
# Metadata: {'Speakers': ['Sissel Hansen'], 'date': {'day': 'Friday', 'start_time': '18:15', 'end_time': '18:30'}}
# ###########
# Content: Title: AI and the technological singularity explained
# Description: No description found
# Date: Friday June 14, 2024 13:00 - 13:45 CEST
# Location: Innovation Stage
# Type:
# Metadata: {'Speakers': ['Jonas Witt'], 'date': {'day': 'Friday', 'start_time': '13:00', 'end_time': '13:45'}}
# ###########
# Content: Title: Highperformance Teams
# Description: No description found
# Date: Friday June 14, 2024 15:00 - 15:45 CEST
# Location: Transformation Stage
# Type: Future Skills, talk |   Zukunft der Arbeit, talk
# Metadata: {'Speakers': ['Michelle Euzet'], 'date': {'day': 'Friday', 'start_time': '15:00', 'end_time': '15:45'}}
# ###########
# Content: Title: Frontend Deveper:innen suchen Arbeitgeber:innen
# Description: No description found
# Date: Friday June 14, 2024 14:00 - 14:45 CEST
# Location: Dock 1
# Type:
# Metadata: {'Speakers': ['Eric Stumper'], 'date': {'day': 'Friday', 'start_time': '14:00', 'end_time': '14:45'}}
# ###########
# Content: Title: Scaling mit Social Entrepreneurship
# Description: No description found
# Date: Friday June 14, 2024 16:00 - 16:45 CEST
# Location: Transformation Stage
# Type: How to Startup
# Metadata: {'Speakers': ['Maxie Matthiessen'], 'date': {'day': 'Friday', 'start_time': '16:00', 'end_time': '16:45'}}
# ###########
# Content: Title: Wärmewende mit Biomasse: Kassenzone Live Podcast mit Martin Lass
# Description: No description found
# Date: Friday June 14, 2024 12:00 - 12:45 CEST
# Location: Waterside Tent
# Type:
# Metadata: {'Speakers': ['Alexander Graf'], 'date': {'day': 'Friday', 'start_time': '12:00', 'end_time': '12:45'}}
# ###########
# Content: Title: From Vision to Innovation: How Northern Europe Shapes the Future of Energy
# Description: No description found
# Date: Friday June 14, 2024 11:00 - 11:45 CEST
# Location: Innovation Stage
# Type: Future of the Planet
# Metadata: {'Speakers': ['Daniel Weber', 'Jannes Ophey', 'Tom Bötticher', 'Dr. Stefan Permien', 'Dr. Anna-Lena Hansen'], 'date': {'day': 'Friday', 'start_time': '11:00', 'end_time': '11:45'}}
# ###########
# Content: Title: Energiezone Live-Podcast mit Northvolt
# Description: No description found
# Date: Friday June 14, 2024 10:00 - 10:45 CEST
# Location: Future Stage
# Type: Future of the Planet
# Metadata: {'Speakers': ['Alexander Graf', 'Nicolas F. Steinbacher'], 'date': {'day': 'Friday', 'start_time': '10:00', 'end_time': '10:45'}}
# ###########
# Content: Title: Ocean Recreation Challenge
# Description: No description found
# Date: Friday June 14, 2024 11:00 - 11:45 CEST
# Location: Rails
# Type: Future of the Ocean, Workshop
# Metadata: {'Speakers': ['Julia Plath', 'Florian Klabes'], 'date': {'day': 'Friday', 'start_time': '11:00', 'end_time': '11:45'}}
# ###########
# Content: Title: Green Unicorn Award + Final Celebration
# Description: No description found
# Date: Friday June 14, 2024 18:00 - 19:00 CEST
# Location: Innovation Stage
# Type:
# Metadata: {'Speakers': ['Wolfgang Kerler'], 'date': {'day': 'Friday', 'start_time': '18:00', 'end_time': '19:00'}}
# ###########
# Content: Title: Blue Bio Economy - the future of the Baltic Sea
# Description: No description found
# Date: Friday June 14, 2024 13:00 - 13:45 CEST
# Location: Beachfront Tent
# Type: Future of the Ocean, Pitch
# Metadata: {'Speakers': ['Julia E. Lange', 'Linda Högbacka'], 'date': {'day': 'Friday', 'start_time': '13:00', 'end_time': '13:45'}}
# ###########
# Content: Title: Green Unicorn Pitch Competition
# Description: No description found
# Date: Friday June 14, 2024 15:00 - 15:45 CEST
# Location: Future Stage
# Type: Future of the Planet, Pitch
# Metadata: {'Speakers': ['Elina Åkerlind', 'Wolfgang Kerler', 'Ony Yan', 'Alexander Lempp', 'Jerry Becker', 'Raitschin Raitschew'], 'date': {'day': 'Friday', 'start_time': '15:00', 'end_time': '15:45'}}
# ###########
# Content: Title: Gründungsstipendiums Pitch Session
# Description: No description found
# Date: Friday June 14, 2024 12:00 - 12:45 CEST
# Location: Robotstage
# Type: How to Startup, Pitch
# Metadata: {'Speakers': ['Broder Fischbach'], 'date': {'day': 'Friday', 'start_time': '12:00', 'end_time': '12:45'}}
# ###########
# Content: Title: Bildung der Zukunft und KI 🤖
# Description: No description found
# Date: Friday June 14, 2024 17:00 - 17:45 CEST
# Location: Future Stage
# Type:
# Metadata: {'Speakers': ['Doris Weßels', 'Gregor Schmalzried', 'Silke Hahn', 'Inken Paland'], 'date': {'day': 'Friday', 'start_time': '17:00', 'end_time': '17:45'}}
# ###########
# Content: Title: Schleswig-Holstein, Scandinavia & the baltics - a new Startup Megaregion
# Description: No description found
# Date: Friday June 14, 2024 17:00 - 17:45 CEST
# Location: Innovation Stage
# Type:
# Metadata: {'Speakers': ['Norma Jensen', 'Stefan Lundgren'], 'date': {'day': 'Friday', 'start_time': '17:00', 'end_time': '17:45'}}
# ###########
# Content: Title: Warum wir eine gerechtere KI brauchen, die alle mit einschließt
# Description: No description found
# Date: Friday June 14, 2024 15:00 - 15:45 CEST
# Location: Forest
# Type: Zukunft der Verwaltung
# Metadata: {'Speakers': ['Zamina Ahmad'], 'date': {'day': 'Friday', 'start_time': '15:00', 'end_time': '15:45'}}
# ###########
# Content: Title: Futures of Music
# Description: No description found
# Date: Friday June 14, 2024 12:00 - 12:45 CEST
# Location: Ocean
# Type: Extending Arts & Reality, panel
# Metadata: {'Speakers': ['Anne Wichmann', 'Matthew Gardiner', 'Sasha Pas'], 'date': {'day': 'Friday', 'start_time': '12:00', 'end_time': '12:45'}}
# ###########
# Content: Title: Community and Belonging in the age of AI: How to Build a Company Culture Powered by Human Potential
# Description: No description found
# Date: Friday June 14, 2024 14:00 - 14:45 CEST
# Location: Transformation Stage
# Type: Zukunft der Arbeit, talk
# Metadata: {'Speakers': ['Pauls Spiers'], 'date': {'day': 'Friday', 'start_time': '14:00', 'end_time': '14:45'}}
# ###########
# Content: Title: Zukunft der Demokratie
# Description: No description found
# Date: Friday June 14, 2024 13:00 - 13:45 CEST
# Location: Future Stage
# Type: Zukunft der Verwaltung, panel
# Metadata: {'Speakers': ['Claudine Nierth', 'Bärbel Boy'], 'date': {'day': 'Friday', 'start_time': '13:00', 'end_time': '13:45'}}
# ###########
# Content: Title: Warum KI und Kunst den Menschen brauchen
# Description: No description found
# Date: Friday June 14, 2024 15:00 - 15:45 CEST
# Location: Waterside Tent
# Type: Extending Arts & Reality, panel
# Metadata: {'Speakers': ['Dr. Julia Schneider aka Doc J Snyder', 'Vladimir Alexeev (Merzmensch)'], 'date': {'day': 'Friday', 'start_time': '15:00', 'end_time': '15:45'}}
# ###########
# Content: Title: AI & Sustainability - A Pigeons Tale
# Description: No description found
# Date: Friday June 14, 2024 11:00 - 11:45 CEST
# Location: Ocean
# Type: Extending Arts & Reality   Future of the Planet
# Metadata: {'Speakers': ['Dr. Julia Schneider aka Doc J Snyder'], 'date': {'day': 'Friday', 'start_time': '11:00', 'end_time': '11:45'}}
# ###########
# Content: Title: KI und Klimaschutz
# Description: No description found
# Date: Friday June 14, 2024 10:00 - 10:45 CEST
# Location: Innovation Stage
# Type: Future of the Planet
# Metadata: {'Speakers': ['Dirk Schrödter'], 'date': {'day': 'Friday', 'start_time': '10:00', 'end_time': '10:45'}}
# ###########
# Content: Title: Abschlusspräsentation Digitalhub.sh
# Description: No description found
# Date: Friday June 14, 2024 12:00 - 12:30 CEST
# Location: Future Stage
# Type: Zukunft der Verwaltung, Award
# Metadata: {'Speakers': ['Anja Voß', 'Dirk Schrödter'], 'date': {'day': 'Friday', 'start_time': '12:00', 'end_time': '12:30'}}
# ###########
# Content: Title: Abschluss des 1. Call for Concept zum Landesprogramm Offene Innovation
# Description: No description found
# Date: Friday June 14, 2024 11:00 - 11:45 CEST
# Location: Future Stage
# Type: Zukunft der Verwaltung, Pitch
# Metadata: {'Speakers': ['Anja Voß', 'Dirk Schrödter'], 'date': {'day': 'Friday', 'start_time': '11:00', 'end_time': '11:45'}}
# ###########
# Content: Title: How To Startup Opensource
# Description: No description found
# Date: Friday June 14, 2024 17:00 - 17:45 CEST
# Location: Forest
# Type:
# Metadata: {'Speakers': ['Matti Nannt'], 'date': {'day': 'Friday', 'start_time': '17:00', 'end_time': '17:45'}}
# ###########

# %%
json_documents = [doc.to_json() for doc in documents]

# %%
with open(f'documents.json', 'w') as file:
    json.dump(json_documents, file)
