# %% [markdown]
# # Download individual event pages

# %%
import requests
import os
import time

# Define the base URL
base_url = "https://waterkantfestival2024.sched.com/"

# Specify the file path for the .txt file
file_path = "links.txt"

# Create a directory to store the downloaded HTML files
os.makedirs('html_pages', exist_ok=True)

# Define the path to the folder
folder_path = 'html_pages'

# List all files in the directory without their extensions
file_names_without_extension = [os.path.splitext(f)[0] for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

# Headers to mimic a browser request
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'
}

# Function to fetch and save the webpage with retry logic
def fetch_and_save(url_extension):
    # Sanitize the URL extension to use as a filename
    sanitized_filename = url_extension.strip().replace('/', '_')
    # Construct the full URL
    full_url = base_url + url_extension.strip()
    # Attempt to fetch the webpage up to 3 times if a 503 error is encountered
    attempts = 3
    for attempt in range(attempts):
        try:
            response = requests.get(full_url, headers=headers)
            response.raise_for_status()  # Raises an HTTPError for bad responses
            # Save the webpage to an HTML file
            with open(os.path.join('html_pages', sanitized_filename + '.html'), 'w', encoding='utf-8') as f:
                f.write(response.text)
            print(f"Saved {sanitized_filename}.html successfully.")
            break  # Exit the loop if successful
        except requests.exceptions.HTTPError as e:
            if e.response.status_code == 503 and attempt < attempts - 1:
                print(f"Attempt {attempt + 1} failed with 503 error, retrying after 5 seconds...")
                time.sleep(5)  # Wait for 5 seconds before retrying
            else:
                print(f"Failed to retrieve {url_extension.strip()}: {e}")
        except requests.RequestException as e:
            print(f"Failed to retrieve {url_extension.strip()}: {e}")
            break  # Exit loop if there's a non-retriable error

# Read the .txt file and process each line
with open(file_path, 'r', encoding='utf-8') as file:
    for num, line in enumerate(file):
        print(num)
        # Use the sanitized filename to check if the file already exists
        sanitized_name = line.strip().replace('/', '_')
        if sanitized_name in file_names_without_extension:
            print("skipped")
            continue
            
        print(line)
        fetch_and_save(line)
# Out:
# 0
# event/1dM8F/funding-for-impact-opening-workshop-for-phds
#
# Saved event_1dM8F_funding-for-impact-opening-workshop-for-phds.html successfully.
# 1
# event/1dJcw/masterclass-souveranitat-bedeutung-tipps-fur-frauen
#
# Saved event_1dJcw_masterclass-souveranitat-bedeutung-tipps-fur-frauen.html successfully.
# 2
# event/1dJct/masterclass-engagement-marketing-wie-unternehmen-die-nachste-generation-kauferinnen-gezielt-ansprechen
#
# Saved event_1dJct_masterclass-engagement-marketing-wie-unternehmen-die-nachste-generation-kauferinnen-gezielt-ansprechen.html successfully.
# 3
# event/1dJck/masterclass-futures-snack-praktische-einfuhrung-in-futures-thinking
#
# Saved event_1dJck_masterclass-futures-snack-praktische-einfuhrung-in-futures-thinking.html successfully.
# 4
# event/1dJcq/masterclass-how-to-build-a-brand-with-purpose-in-the-age-of-ai
#
# Saved event_1dJcq_masterclass-how-to-build-a-brand-with-purpose-in-the-age-of-ai.html successfully.
# 5
# event/1dJcn/masterclass-verhandlungsfuhrung-fur-fuhrungskrafte-von-unternehmen-und-startups
#
# Saved event_1dJcn_masterclass-verhandlungsfuhrung-fur-fuhrungskrafte-von-unternehmen-und-startups.html successfully.
# 6
# event/1dM8s/grand-opening
#
# Saved event_1dM8s_grand-opening.html successfully.
# 7
# event/1dMA8/deep-sea-ar-experience
#
# Saved event_1dMA8_deep-sea-ar-experience.html successfully.
# 8
# event/1dJbC/get-to-know-artificial-intelligence-center-hamburg
#
# Saved event_1dJbC_get-to-know-artificial-intelligence-center-hamburg.html successfully.
# 9
# event/1dM8I/pitch-competition-startup-camp-schleswig-holstein-by-plug-play
#
# Saved event_1dM8I_pitch-competition-startup-camp-schleswig-holstein-by-plug-play.html successfully.
# 10
# event/1dM9A/investment-vernissage-invitation-only
#
# Saved event_1dM9A_investment-vernissage-invitation-only.html successfully.
# 11
# event/1dM8p/prompt-battle
#
# Saved event_1dM8p_prompt-battle.html successfully.
# 12
# event/1dJd8/verkundung-sieger-plug-play-pitch-competition
#
# Saved event_1dJd8_verkundung-sieger-plug-play-pitch-competition.html successfully.
# 13
# event/1dM8m/music-by-marlot-karpov
#
# Saved event_1dM8m_music-by-marlot-karpov.html successfully.
# 14
# event/1dM9k/early-stage-pitches
#
# Saved event_1dM9k_early-stage-pitches.html successfully.
# 15
# event/1dJd5/future-of-education
#
# Saved event_1dJd5_future-of-education.html successfully.
# 16
# event/1dJau/how-to-businessplan
#
# Saved event_1dJau_how-to-businessplan.html successfully.
# 17
# event/1dJcA/no-code-innovation-dank-hi-ki
#
# Saved event_1dJcA_no-code-innovation-dank-hi-ki.html successfully.
# 18
# event/1dM9z/tech-for-good-immersive-storytelling-for-social-environmental-impact
#
# Saved event_1dM9z_tech-for-good-immersive-storytelling-for-social-environmental-impact.html successfully.
# 19
# event/1dMAN/energiezone-live-podcast-mit-northvolt
#
# Saved event_1dMAN_energiezone-live-podcast-mit-northvolt.html successfully.
# 20
# event/1dMBL/ki-und-klimaschutz
#
# Saved event_1dMBL_ki-und-klimaschutz.html successfully.
# 21
# event/1dM9D/adding-accessiblity-made-it-worse-but-why
#
# Saved event_1dM9D_adding-accessiblity-made-it-worse-but-why.html successfully.
# 22
# event/1dM89/brand-design-for-impact-founders
#
# Saved event_1dM89_brand-design-for-impact-founders.html successfully.
# 23
# event/1dM9q/best-practice-mental-health-im-unternehmen
#
# Saved event_1dM9q_best-practice-mental-health-im-unternehmen.html successfully.
# 24
# event/1dM7i/ethische-ki
#
# Saved event_1dM7i_ethische-ki.html successfully.
# 25
# event/1dM9S/food-match-making-innovationen-im-foodbereich
#
# Saved event_1dM9S_food-match-making-innovationen-im-foodbereich.html successfully.
# 26
# event/1dM80/making-social-work-future-proof
#
# Saved event_1dM80_making-social-work-future-proof.html successfully.
# 27
# event/1dMBI/ai-sustainability-a-pigeons-tale
#
# Saved event_1dMBI_ai-sustainability-a-pigeons-tale.html successfully.
# 28
# event/1dMAQ/ocean-recreation-challenge
#
# Saved event_1dMAQ_ocean-recreation-challenge.html successfully.
# 29
# event/1dJdE/creating-circular-cities
#
# Saved event_1dJdE_creating-circular-cities.html successfully.
# 30
# event/1dMAl/from-vision-to-innovation-how-northern-europe-shapes-the-future-of-energy
#
# Saved event_1dMAl_from-vision-to-innovation-how-northern-europe-shapes-the-future-of-energy.html successfully.
# 31
# event/1dM97/zukunftsdenken-fur-den-mittelstand-trainieren
#
# Saved event_1dM97_zukunftsdenken-fur-den-mittelstand-trainieren.html successfully.
# 32
# event/1dJcz/where-is-the-money-fordermoglichkeit-fur-grunderinnen
#
# Saved event_1dJcz_where-is-the-money-fordermoglichkeit-fur-grunderinnen.html successfully.
# 33
# event/1dJcP/lean-startup-fur-impact-grunderinnen
#
# Saved event_1dJcP_lean-startup-fur-impact-grunderinnen.html successfully.
# 34
# event/1dM86/phd-match-making
#
# Saved event_1dM86_phd-match-making.html successfully.
# 35
# event/1dM9n/nachhaltigkeit-als-unternehmenspraxis
#
# Saved event_1dM9n_nachhaltigkeit-als-unternehmenspraxis.html successfully.
# 36
# event/1dMBR/abschluss-des-1-call-for-concept-zum-landesprogramm-offene-innovation
#
# Saved event_1dMBR_abschluss-des-1-call-for-concept-zum-landesprogramm-offene-innovation.html successfully.
# 37
# event/1dMBO/abschlussprasentation-digitalhubsh
#
# Saved event_1dMBO_abschlussprasentation-digitalhubsh.html successfully.
# 38
# event/1dM91/food-match-making-mittelstand-meets-startup
#
# Saved event_1dM91_food-match-making-mittelstand-meets-startup.html successfully.
# 39
# event/1dJbm/ki-meetup-aric-kielai-codingwaterkant
#
# Saved event_1dJbm_ki-meetup-aric-kielai-codingwaterkant.html successfully.
# 40
# event/1dJd2/past-future-of-ai-content-creation-by-an-openai-ambassador
#
# Saved event_1dJd2_past-future-of-ai-content-creation-by-an-openai-ambassador.html successfully.
# 41
# event/1dMAK/warmewende-mit-biomasse-kassenzone-live-podcast-mit-martin-lass
#
# Saved event_1dMAK_warmewende-mit-biomasse-kassenzone-live-podcast-mit-martin-lass.html successfully.
# 42
# event/1dMB6/futures-of-music
#
# Saved event_1dMB6_futures-of-music.html successfully.
# 43
# event/1dM83/how-to-zero-waste
#
# Saved event_1dM83_how-to-zero-waste.html successfully.
# 44
# event/1dM7u/mobilitat-der-zukunft
#
# Saved event_1dM7u_mobilitat-der-zukunft.html successfully.
# 45
# event/1dJbj/erfolg-mit-tiktok-im-mittelstand
#
# Saved event_1dJbj_erfolg-mit-tiktok-im-mittelstand.html successfully.
# 46
# event/1dMAW/grundungsstipendiums-pitch-session
#
# Saved event_1dMAW_grundungsstipendiums-pitch-session.html successfully.
# 47
# event/1dM9M/fuhrungsmodelle-der-zukunft
#
# Saved event_1dM9M_fuhrungsmodelle-der-zukunft.html successfully.
# 48
# event/1dMAc/ai-and-the-technological-singularity-explained
#
# Saved event_1dMAc_ai-and-the-technological-singularity-explained.html successfully.
# 49
# event/1dJbL/co2-neutrales-bauen-wunsch-und-wirklichkeit
#
# Saved event_1dJbL_co2-neutrales-bauen-wunsch-und-wirklichkeit.html successfully.
# 50
# event/1dM9J/die-zukunfte-des-internets-sind-feministisch
#
# Saved event_1dM9J_die-zukunfte-des-internets-sind-feministisch.html successfully.
# 51
# event/1dJby/dos-und-donts-beim-implementieren-von-ki-im-mittelstand
#
# Saved event_1dJby_dos-und-donts-beim-implementieren-von-ki-im-mittelstand.html successfully.
# 52
# event/1dM8g/follow-up-fuhrungsmodelle-der-zukunft
#
# Saved event_1dM8g_follow-up-fuhrungsmodelle-der-zukunft.html successfully.
# 53
# event/1dJbd/innovationsraum-hamburg-schleswig-holstein
#
# Saved event_1dJbd_innovationsraum-hamburg-schleswig-holstein.html successfully.
# 54
# event/1dM8X/mindful-startup-training
#
# Saved event_1dM8X_mindful-startup-training.html successfully.
# 55
# event/1dMA5/extended-learning-wissensvermittlung-durch-immersive-medien
#
# Saved event_1dMA5_extended-learning-wissensvermittlung-durch-immersive-medien.html successfully.
# 56
# event/1dMAT/blue-bio-economy-the-future-of-the-baltic-sea
#
# Saved event_1dMAT_blue-bio-economy-the-future-of-the-baltic-sea.html successfully.
# 57
# event/1dM9G/content-creation-mit-ki
#
# Saved event_1dM9G_content-creation-mit-ki.html successfully.
# 58
# event/1dMBC/zukunft-der-demokratie
#
# Saved event_1dMBC_zukunft-der-demokratie.html successfully.
# 59
# event/1dM94/behind-the-scenes-of-impact-investment
#
# Saved event_1dM94_behind-the-scenes-of-impact-investment.html successfully.
# 60
# event/1dJc1/black-female-business
#
# Saved event_1dJc1_black-female-business.html successfully.
# 61
# event/1dJbI/dritte-orte-die-bibliothek-der-zukunft
#
# Saved event_1dJbI_dritte-orte-die-bibliothek-der-zukunft.html successfully.
# 62
# event/1dMAf/frontend-deveperinnen-suchen-arbeitgeberinnen
#
# Saved event_1dMAf_frontend-deveperinnen-suchen-arbeitgeberinnen.html successfully.
# 63
# event/1dM8U/meditationsworkshop
#
# Saved event_1dM8U_meditationsworkshop.html successfully.
# 64
# event/1dJbO/wann-wird-ai-endlich-langweilig-ein-optmistischer-blick-auf-die-zukunft
#
# Saved event_1dJbO_wann-wird-ai-endlich-langweilig-ein-optmistischer-blick-auf-die-zukunft.html successfully.
# 65
# event/1dJbs/why-europe-is-leading-the-way-in-open-source-ai
#
# Saved event_1dJbs_why-europe-is-leading-the-way-in-open-source-ai.html successfully.
# 66
# event/1dM8j/anfangermindset-als-grundlage-von-innovation
#
# Saved event_1dM8j_anfangermindset-als-grundlage-von-innovation.html successfully.
# 67
# event/1dM9V/growth-stage-pitches-powered-by-kitz
#
# Saved event_1dM9V_growth-stage-pitches-powered-by-kitz.html successfully.
# 68
# event/1dMB9/community-and-belonging-in-the-age-of-ai-how-to-build-a-company-culture-powered-by-human-potential
#
# Saved event_1dMB9_community-and-belonging-in-the-age-of-ai-how-to-build-a-company-culture-powered-by-human-potential.html successfully.
# 69
# event/1dM9Y/organisationsmodelle-der-zukunft-alles-holo-oder-was
#
# Saved event_1dM9Y_organisationsmodelle-der-zukunft-alles-holo-oder-was.html successfully.
# 70
# event/1dJb9/verwaltung-der-zukunft
#
# Saved event_1dJb9_verwaltung-der-zukunft.html successfully.
# 71
# event/1dM8v/zukunft-des-journalismus
#
# Saved event_1dM8v_zukunft-des-journalismus.html successfully.
# 72
# event/1dJc4/cofounder-mix-match
#
# Saved event_1dJc4_cofounder-mix-match.html successfully.
# 73
# event/1dM8R/holy-moly-wie-soziale-innovationen-entstehen
#
# Saved event_1dM8R_holy-moly-wie-soziale-innovationen-entstehen.html successfully.
# 74
# event/1dJbR/open-source-stammtisch
#
# Saved event_1dJbR_open-source-stammtisch.html successfully.
# 75
# event/1dM9P/status-quo-energiewende
#
# Saved event_1dM9P_status-quo-energiewende.html successfully.
# 76
# event/1dMBF/warum-ki-und-kunst-den-menschen-brauchen
#
# Saved event_1dMBF_warum-ki-und-kunst-den-menschen-brauchen.html successfully.
# 77
# event/1dMAu/green-unicorn-pitch-competition
#
# Saved event_1dMAu_green-unicorn-pitch-competition.html successfully.
# 78
# event/1dJcV/how-to-chatbot-ki-nutzbar-machen
#
# Saved event_1dJcV_how-to-chatbot-ki-nutzbar-machen.html successfully.
# 79
# event/1dMAE/highperformance-teams
#
# Saved event_1dMAE_highperformance-teams.html successfully.
# 80
# event/1dM9b/livepodcast-equality-365-der-erste-inklusive-incubator
#
# Saved event_1dM9b_livepodcast-equality-365-der-erste-inklusive-incubator.html successfully.
# 81
# event/1dM7r/wie-blicken-vcs-auf-early-stage-startups
#
# Saved event_1dM7r_wie-blicken-vcs-auf-early-stage-startups.html successfully.
# 82
# event/1dMA2/reconceptualize-value-unternehmerische-wertschopfung-fur-die-sozial-okologische-transformation
#
# Saved event_1dMA2_reconceptualize-value-unternehmerische-wertschopfung-fur-die-sozial-okologische-transformation.html successfully.
# 83
# event/1dMB3/warum-wir-eine-gerechtere-ki-brauchen-die-alle-mit-einschliesst
#
# Saved event_1dMB3_warum-wir-eine-gerechtere-ki-brauchen-die-alle-mit-einschliesst.html successfully.
# 84
# event/1dM8C/bots-company
#
# Saved event_1dM8C_bots-company.html successfully.
# 85
# event/1dM8d/die-zukunfte-von-social-media
#
# Saved event_1dM8d_die-zukunfte-von-social-media.html successfully.
# 86
# event/1dJcJ/generative-ki-als-copilot-in-der-grundung
#
# Saved event_1dJcJ_generative-ki-als-copilot-in-der-grundung.html successfully.
# 87
# event/1dJcG/p-p-meeting
#
# Saved event_1dJcG_p-p-meeting.html successfully.
# 88
# event/1dJbX/tinkertank-eksh-abschlussprasentation
#
# Saved event_1dJbX_tinkertank-eksh-abschlussprasentation.html successfully.
# 89
# event/1dM9w/gemeinwohlokonomie-als-recruitingsbooster
#
# Saved event_1dM9w_gemeinwohlokonomie-als-recruitingsbooster.html successfully.
# 90
# event/1dMAi/scaling-mit-social-entrepreneurship
#
# Saved event_1dMAi_scaling-mit-social-entrepreneurship.html successfully.
# 91
# event/1dJch/startup-sessions-mit-vision-period
#
# Saved event_1dJch_startup-sessions-mit-vision-period.html successfully.
# 92
# event/1dM9t/raus-aus-der-grossen-erschopfung
#
# Saved event_1dM9t_raus-aus-der-grossen-erschopfung.html successfully.
# 93
# event/1dM8L/egov-meetup
#
# Saved event_1dM8L_egov-meetup.html successfully.
# 94
# event/1dJcb/12minme-hh-meets-kiel-better-together
#
# Saved event_1dJcb_12minme-hh-meets-kiel-better-together.html successfully.
# 95
# event/1dMAx/bildung-der-zukunft-und-ki
#
# Saved event_1dMAx_bildung-der-zukunft-und-ki.html successfully.
# 96
# event/1dJbU/esport-job-session
#
# Saved event_1dJbU_esport-job-session.html successfully.
# 97
# event/1dJcD/how-to-become-a-business-angel
#
# Saved event_1dJcD_how-to-become-a-business-angel.html successfully.
# 98
# event/1dZ6V/how-to-startup-opensource
#
# Saved event_1dZ6V_how-to-startup-opensource.html successfully.
# 99
# event/1dJb3/neue-herausforderungen-im-bereich-von-open-source-ai-llm-security
#
# Saved event_1dJb3_neue-herausforderungen-im-bereich-von-open-source-ai-llm-security.html successfully.
# 100
# event/1dMB0/schleswig-holstein-scandinavia-the-baltics-a-new-startup-megaregion
#
# Saved event_1dMB0_schleswig-holstein-scandinavia-the-baltics-a-new-startup-megaregion.html successfully.
# 101
# event/1dJdB/social-entrepreneurship-pitch-session
#
# Saved event_1dJdB_social-entrepreneurship-pitch-session.html successfully.
# 102
# event/1dJba/start-a-startup-pitch-sessions
#
# Saved event_1dJba_start-a-startup-pitch-sessions.html successfully.
# 103
# event/1dM9h/early-stage-pitches-demo-day-start-a-startup
#
# Saved event_1dM9h_early-stage-pitches-demo-day-start-a-startup.html successfully.
# 104
# event/1dMAr/green-unicorn-award-final-celebration
#
# Saved event_1dMAr_green-unicorn-award-final-celebration.html successfully.
# 105
# event/1dMAB/launch-of-startup-guide-kielregion
# Saved event_1dMAB_launch-of-startup-guide-kielregion.html successfully.

# %% [markdown]
# Check that amount of html pages is equal to amount of links

# %%
import os

# Define the path to the folder
folder_path = 'html_pages'

# List all files in the directory without their extensions
file_names_without_extension = [os.path.splitext(f)[0] for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

# Print the number of files
print(f"Number of files in '{folder_path}': {len(file_names_without_extension)}")
# Print the filenames without extensions
#print("Filenames without extension:", file_names_without_extension)
# Out:
# Number of files in 'html_pages': 106

# %%
# Specify the path to your .txt file
file_path = 'links.txt'

# Initialize a counter
line_count = 0

# Open the file and read through each line to count them
with open(file_path, 'r') as file:
    for line in file:
        line_count += 1

# Print the total number of lines
print(f"The file has {line_count} lines.")
# Out:
# The file has 106 lines.

# %% [markdown]
# Let's make sure there are no duplicates in our links

# %%
# Path to the file
file_path = 'links.txt'

# Dictionary to hold lines and their line numbers
lines_seen = {}
duplicates = {}

# Read the file
with open(file_path, 'r') as file:
    for line_number, line in enumerate(file, 1):
        # Remove any leading/trailing whitespace
        stripped_line = line.strip()
        
        # Check if the line is already seen
        if stripped_line in lines_seen:
            # If it's a duplicate, add the current line number
            if stripped_line in duplicates:
                duplicates[stripped_line].append(line_number)
            else:
                duplicates[stripped_line] = [lines_seen[stripped_line], line_number]
        else:
            # If it's not seen, remember the line with its line number
            lines_seen[stripped_line] = line_number

# Output the results
for line, line_nums in duplicates.items():
    print(f"Duplicate line: '{line}' found on line numbers: {line_nums}")

# %%
duplicates
# Out:
# {}

# %% [markdown]
# ## Processing the html files to json

# %%
import os
from bs4 import BeautifulSoup

# Directory containing HTML files
directory_path = 'html_pages'

# Iterate through each file in the directory
for filename in os.listdir(directory_path)[2:]:
    # Check if the file is an HTML file
    if filename.endswith('.html'):
        # Construct full file path
        file_path = os.path.join(directory_path, filename)
        
        # Open and read the HTML file
        with open(file_path, 'r', encoding='utf-8') as file:
            html_content = file.read()
        
        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(html_content, 'html.parser')

        # Extract content of divs by their class
        tip_description = soup.find("div", class_="tip-description").get_text() if soup.find("div", class_="tip-description") else "No description found"
        # find the div with class 'tip-roles'
        # find all divs that have the class "sched-person-session"
        sessions = soup.find_all("div", class_="sched-person-session")
        
        # extract the text from the h2 element within each session div, if it exists
        speakers = [session.find("h2").get_text(strip=True) for session in sessions if session.find("h2")]
        #tip_roles = soup.find("div", class_="tip-roles").get_text() if soup.find("div", class_="tip-roles") else "No roles found"
        event_details = soup.find("div", class_="sched-event-details-timeandplace").get_text() if soup.find("div", class_="sched-event-details-timeandplace") else "No event details found"
        event_type = soup.find("div", class_="sched-event-type").get_text() if soup.find("div", class_="sched-event-type") else "No event type found"
        a_tag = soup.select_one('span[class^="event"] a')

        # Extract the text from the found <a> tag
        if a_tag:
            title = a_tag.get_text(strip=True)
        else:
            print("No matching element found.")
        # Print extracted data
        print(f"File: {filename}")
        print("Title:", title)
        print("Description:", tip_description)
        print("Speakers:", speakers)
        #print("Event Details:", event_details)
        print("date:", event_details.strip().split('\n')[0])
        print("location:", event_details.strip().split('\n')[1])
        print("type:", event_type.strip())
        print("-" * 40)  # Separator for readability between files
        break
# Out:
# File: event_1dJb9_verwaltung-der-zukunft.html
# Title: Verwaltung der Zukunft
# Description: No description found
# Speakers: ['Thilak Mahendran']
# date: Friday June 14, 2024 14:00 - 14:45 CEST
# location: Tiny Rathaus
# type: Zukunft der Verwaltung, talk
# ----------------------------------------

# %%
import os
import json
from bs4 import BeautifulSoup

# Directory containing HTML files
directory_path = 'html_pages'
output_directory = 'json'

# Ensure the output directory exists
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Iterate through each file in the directory
for filename in os.listdir(directory_path):
    # Check if the file is an HTML file
    if filename.endswith('.html'):
        # Construct full file path
        file_path = os.path.join(directory_path, filename)
        
        # Open and read the HTML file
        with open(file_path, 'r', encoding='utf-8') as file:
            html_content = file.read()
        
        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(html_content, 'html.parser')

        # Extract content of divs by their class
        tip_description = soup.find("div", class_="tip-description").get_text() if soup.find("div", class_="tip-description") else "No description found"
        sessions = soup.find_all("div", class_="sched-person-session")
        speakers = [session.find("h2").get_text(strip=True) for session in sessions if session.find("h2")]
        event_details = soup.find("div", class_="sched-event-details-timeandplace").get_text() if soup.find("div", class_="sched-event-details-timeandplace") else "No event details found"
        event_type = soup.find("div", class_="sched-event-type").get_text() if soup.find("div", class_="sched-event-type") else "No event type found"
        a_tag = soup.select_one('span[class^="event"] a')
        
        # Extract the text from the found <a> tag
        title = a_tag.get_text(strip=True) if a_tag else "No title found"

        # Prepare data dictionary
        data = {
            "Title": title,
            "Description": tip_description,
            "Speakers": speakers,
            "Date": event_details.strip().split('\n')[0],
            "Location": event_details.strip().split('\n')[1],
            "Type": event_type.strip()
        }

        # Define the output JSON filename
        output_filename = os.path.join(output_directory, os.path.splitext(filename)[0] + '.json')
        
        # Write data to a JSON file
        with open(output_filename, 'w', encoding='utf-8') as json_file:
            json.dump(data, json_file, indent=4)
